# %%
import pickle

# %%
## Saving pickle file

#after model trainig
model_trained = "any model trained"
pickle.dump(model_trained,open('filename','wb'))

# %%
## loading pickel file
model = pickle.load(open('../pickle_files/pro01_regressor.pkl','rb'))

# %%
model.predict([[1,2,3,4,5,6,7,8]])
# Out:
# array([-9.88471576])
